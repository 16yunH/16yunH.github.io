# %% [markdown]
# <a href="https://colab.research.google.com/github/16yunH/16yunH.github.io/blob/master/notebooks/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Use W&B offline

# %%
# !wandb offline
# Out:
# W&B offline. Running your script from this directory will only write metadata locally. Use wandb disabled to completely turn off W&B.

# %% [markdown]
# ## **Or** login using an API from your W&B account

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin

# %% [markdown]
# ## Now you are set to run the demo!

# %%
import subprocess
import sys

print("import finished")

process = subprocess.Popen(
  [
    "uvx",
    "--refresh",
    "--from",
    "mjlab==0.1.0",
    "--with",
    "mujoco-warp @ git+https://github.com/google-deepmind/mujoco_warp@486642c3fa262a989b482e0e506716d5793d61a9",
    "demo",
  ],
  stdout=subprocess.PIPE,
  stderr=subprocess.STDOUT,
  universal_newlines=True,
  bufsize=1,
)

for line in process.stdout:
  print(line, end="")
  sys.stdout.flush()

  if "serving" in line.lower() or "running on" in line.lower() or "8081" in line:
    print("\n" + "=" * 50)
    print("✅ Server is running! Execute the next cell to view.")
    print("=" * 50)
    break
# Out:
# Installed 121 packages in 896ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-243940617.py in <cell line: 0>()
#      18 )
#      19
# ---> 20 for line in process.stdout:
#      21   print(line, end="")
#      22   sys.stdout.flush()
#
# KeyboardInterrupt:

# %%
from google.colab import output

output.serve_kernel_port_as_iframe(8081)
